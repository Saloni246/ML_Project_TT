# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # READING DATASET

# %%
df=pd.read_csv('time_series_2019-ncov-Confirmed.csv')
df
# Out:
#     Province/State Country/Region       Lat      Long  1/22/20  1/23/20  \
# 0              NaN       Thailand        15       101        2        3
# 1              NaN          Japan        36       138        2        1
# 2              NaN      Singapore    1.2833  103.8333        0        1
# 3              NaN          Nepal   28.1667     84.25        0        0
# 4              NaN       Malaysia       2.5     112.5        0        0
# ..             ...            ...       ...       ...      ...      ...
# 482            NaN       Dominica    15.415   /61.371        0        0
# 483            NaN        Grenada   12.1165   /61.679        0        0
# 484            NaN     Mozambique  /18.6657   35.5296        0        0
# 485            NaN          Syria   34.8021   38.9968        0        0
# 486            NaN    Timor/Leste   /8.8742  125.7275        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/13/20  3/14/20  3/15/20  \
# ...

# %%
df.dropna(axis=1)
# Out:
#     Country/Region       Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0         Thailand        15       101        2        3        5        7
# 1            Japan        36       138        2        1        2        2
# 2        Singapore    1.2833  103.8333        0        1        3        3
# 3            Nepal   28.1667     84.25        0        0        0        1
# 4         Malaysia       2.5     112.5        0        0        0        3
# ..             ...       ...       ...      ...      ...      ...      ...
# 482       Dominica    15.415   /61.371        0        0        0        0
# 483        Grenada   12.1165   /61.679        0        0        0        0
# 484     Mozambique  /18.6657   35.5296        0        0        0        0
# 485          Syria   34.8021   38.9968        0        0        0        0
# 486    Timor/Leste   /8.8742  125.7275        0        0        0        0
#
# ...

# %% [markdown]
# ### SELECTING COLUMNS CONTAINING ONLY DATES

# %%
df1=df.iloc[:,4:65]
df1
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 0          2        3        5        7        8        8       14       14
# 1          2        1        2        2        4        4        7        7
# 2          0        1        3        3        4        5        7        7
# 3          0        0        0        1        1        1        1        1
# 4          0        0        0        3        4        4        4        7
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 482        0        0        0        0        0        0        0        0
# 483        0        0        0        0        0        0        0        0
# 484        0        0        0        0        0        0        0        0
# 485        0        0        0        0        0        0        0        0
# 486        0        0        0        0        0        0        0        0
#
# ...

# %%
#printing percentage of each column depending on 0 confirmed cases

a=print (df1.isin([0]).mean())
# Out:
# 1/22/20    0.940452
# 1/23/20    0.924025
# 1/24/20    0.917864
# 1/25/20    0.911704
# 1/26/20    0.899384
#              ...
# 3/18/20    0.445585
# 3/19/20    0.433265
# 3/20/20    0.414784
# 3/21/20    0.404517
# 3/22/20    0.394251
# Length: 61, dtype: float64

# %%
#Dropping all the columns or dates having 0 confirmed cases above 70% of the total

df2 = df1.loc[:, df1.isin([0]).mean() < .70]       #named this new dataset as df2
df2
# Out:
#      03-04-2020  03-05-2020  03-06-2020  03-07-2020  03-08-2020  03-09-2020  \
# 0            43          47          48          50          50          50
# 1           331         360         420         461         502         511
# 2           110         117         130         138         150         150
# 3             1           1           1           1           1           1
# 4            50          50          83          93          99         117
# ..          ...         ...         ...         ...         ...         ...
# 482           0           0           0           0           0           0
# 483           0           0           0           0           0           0
# 484           0           0           0           0           0           0
# 485           0           0           0           0           0           0
# 486           0           0           0           0           0           0
#
# ...

# %% [markdown]
# # COUNTRY-WISE PLOT

# %%
labels=df.iloc[:,1] #selcting country column as label from original dataset
y=df.iloc[:,-1]     #selecting total number of cases from last column
plt.figure(figsize=(30,10))

#Drawing Pie-Chart
patches,text=plt.pie(y)
plt.title('CONFIRMED CASES COUNTRY-WISE',size=24)
plt.legend(patches,labels,title='COUNTRIES',loc='centre left',prop={'size':10},bbox_to_anchor=(-0.1, 1.))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Unrecognized location 'centre left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %% [markdown]
# # DATE-WISE PLOT

# %%
#finding sum of each column from new dataset df2
df2.sum(axis=0)
# Out:
# 03-04-2020     95120
# 03-05-2020     97882
# 03-06-2020    101784
# 03-07-2020    105821
# 03-08-2020    109795
# 03-09-2020    113561
# 03-10-2020    118592
# 03-11-2020    125865
# 03-12-2020    128343
# 3/13/20       145193
# 3/14/20       156094
# 3/15/20       167446
# 3/16/20       181527
# 3/17/20       197142
# 3/18/20       214910
# 3/19/20       242708
# 3/20/20       272166
# 3/21/20       304524
# 3/22/20       335955
# dtype: int64

# %%
dates=df2.keys()
total_cases_on_date=[]
for i in dates[:]:
    sum_of_cases=df2[i].sum()
    total_cases_on_date.append(sum_of_cases)
    print(f'{i}: {sum_of_cases}')
# Out:
# 03-04-2020: 95120
# 03-05-2020: 97882
# 03-06-2020: 101784
# 03-07-2020: 105821
# 03-08-2020: 109795
# 03-09-2020: 113561
# 03-10-2020: 118592
# 03-11-2020: 125865
# 03-12-2020: 128343
# 3/13/20: 145193
# 3/14/20: 156094
# 3/15/20: 167446
# 3/16/20: 181527
# 3/17/20: 197142
# 3/18/20: 214910
# 3/19/20: 242708
# 3/20/20: 272166
# 3/21/20: 304524
# 3/22/20: 335955

# %%
#Drawing Pie-Chart

plt.figure(figsize=(30,10))

plt.pie(total_cases_on_date,labels=dates,autopct='%1.0f%%', pctdistance=0.75,labeldistance=1.05)
plt.title('CONFIRMED CASES DATE-WISE',size=24)
plt.legend(dates,title='DATES',loc='centre left',prop={'size':10},bbox_to_anchor=(-0.1, 1.))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'centre left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %% [markdown]
# # CONTINENT-WISE PLOT

# %%
cont=pd.read_csv('c2c.csv') #reading continent and country dataset
cont
# Out:
#          Continent    Country
# 0           Africa    Algeria
# 1           Africa     Angola
# 2           Africa      Benin
# 3           Africa   Botswana
# 4           Africa    Burkina
# ..             ...        ...
# 189  South America   Paraguay
# 190  South America       Peru
# 191  South America   Suriname
# 192  South America    Uruguay
# 193  South America  Venezuela
#
# [194 rows x 2 columns]

# %%
#Making dictionary of country name and total cases in each country
country_names=dict()

for i in range(487):
    country_names[df.iloc[i][1]]=country_names.get(df.iloc[i][1],0)+df.iloc[i][-1]

# %%
#Making dictionary of continent name and total cases in each continent
continent_names=dict()

for i in country_names:
    names=cont.loc[cont['Country']==i]
    if len(names)>0:
        continent_names[names.iloc[0][0]]=continent_names.get(names.iloc[0][0],0)+country_names[i]
        
continent_names      #printing total cases in each continent
# Out:
# {'Asia': 113013,
#  'North America': 35349,
#  'Oceania': 1316,
#  'Europe': 162094,
#  'Africa': 1015,
#  'South America': 4096}

# %%
#Drawing Pie-Chart

plt.figure(figsize=(30,10))
x=continent_names.values()
label=continent_names.keys()
explode=(0,0,0.1,0,0.3,0)

plt.pie(x,labels=label,autopct='%1.0f%%', pctdistance=0.75,labeldistance=1.09,explode=explode)
plt.title('CONFIRMED CASES CONTINENT-WISE',size=24)
plt.legend(label,title='CONTINENTS',loc='centre left',prop={'size':10},bbox_to_anchor=(-0.1, 1.))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Unrecognized location 'centre left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   # Remove the CWD from sys.path while we load stuff.
